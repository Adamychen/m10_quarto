# %% [markdown]
# # Acerca de
#
# Módulo 10 del Máster en Data Science & Big Data.
#
# **IA Generativa para Data Science** — 3,0 ECTS \| 75 horas \| Modalidad
# a distancia \| Nivel técnico.
#
# ------------------------------------------------------------------------
#
# ## Autoría
#
# **Departamento de Ciencias de la Computación e Inteligencia
# Artificial**
# Universidad de Sevilla
#
# - **Adam Leiyi Chen Abolacio** — `achen@us.es`
# - **Fernando Sancho Caparrini** — `fsancho@us.es`
